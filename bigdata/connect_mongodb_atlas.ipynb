# %%
import pandas as pd
from pymongo import MongoClient

# %% [markdown]
# Initialize Connection

# %%
uri = "mongodb+srv://bigdatateam:BigData2026@bigdatadb.xlinxyc.mongodb.net/amazon_reviews_db?retryWrites=true&w=majority"

# %% [markdown]
# Get Connection

# %%
client = MongoClient(uri)
db = client['amazon_reviews_db']
collection = db['full_reviews']

# %% [markdown]
# Retrieve top 100 records

# %%
print('Getting data from Cloud...')
data = list(collection.find().limit(1)) # Lấy record đầu tiên
# Out:
# Getting data from Cloud...

# %%
print(data)
# Out:
# [{'_id': ObjectId('69e6466d33457e1cf90e187a'), 'Unnamed: 0': 0, 'i': 1, 'p': 'B001E4KFG0', 'u': 'A3SGXH7AUHU8GW', 'pn': 'delmartian', 'hn': 1, 'hd': 1, 's': 5, 'tm': 1303862400, 'sm': 'Good Quality Dog Food', 't': 'I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.', 'url': 'https://www.amazon.com/dp/B001E4KFG0'}]
